# %%
# Import Packages
#Basic packages
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Hierarchy Cluster module.
import scipy.cluster.hierarchy as shc

#Standardizing features. Use the StandardScaler module from scikit-learn
from sklearn.preprocessing import StandardScaler

#K-mean, PCA, Normalize and Clustering modules. Use the scikit-learn packages
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize

#Correlation Circle.
from mlxtend.plotting import plot_pca_correlation_graph

# %%
Course_perYear = pd.read_csv('Data/Ressources_perTeacher.csv').reset_index()
Course_perYear.head(5)
# Out:
#    index  Course_ID  Course_Duration  Course_Duration_MOOC  Year  \
# 0      0          1               13                     1  2013
# 1      1          2               90                    21  2013
# 2      2          3               56                    35  2013
# 3      3          4               51                    33  2013
# 4      4          5               19                     5  2013
#
#    Courses_perYear  Duration_Video  Duration_Quiz  Duration_Exam  \
# 0             2418               0              1              0
# 1             2418               7             11              3
# 2             2418              17             16              2
# 3             2418              23              9              1
# 4             2418               2              2              1
#
#    Number_Video  ...  Number_Video_1H  Number_Video_2H  Number_video_3H  \
# 0             0  ...                0                0                0
# ...

# %%
Ress_pTeacher = Course_perYear[['Course_Duration', 'Course_Duration_MOOC', 'Duration_Video', 'Duration_Quiz', 'Duration_Exam']]

# %%
#Define the dataset for the correlation circle

#Normalize the values of the dataset
Ress_pTeacher = Ress_pTeacher.values
#Ress_pTeacher_norm = Ress_pTeacher / Course_PCA.std(axis=0) # Normalizing the feature columns is recommended

#Select the names of the columns
Ress_pTeacher_feature_names = ['Course_Duration', 'Course_Duration_MOOC', 'Duration_Video', 'Duration_Quiz', 'Duration_Exam']

#Set the figure and the graph
figure1, correlation_matrix1 = plot_pca_correlation_graph(Ress_pTeacher, 
                                                        Ress_pTeacher_feature_names,
                                                        dimensions=(1, 2),
                                                        figure_axis_size=10)

#Display the plot
plt.show()
